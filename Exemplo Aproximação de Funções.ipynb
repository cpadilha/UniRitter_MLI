# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(0, 20, 1e-3)

# %%
y = np.sin(x)

# %%
x = x.reshape((10000, 1))

# %%
plt.plot(x, y)

# %% [markdown]
# <h2>Criando o modelo</h2>

# %%
from sklearn.neural_network import MLPRegressor

# %%
mlp = MLPRegressor()
mlp.fit(x, y)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %% [markdown]
# <h2>Testando</h2>

# %%
x2 = np.arange(11, 20, 5e-2)
x2 = x2.reshape((len(x2), 1))

# %%
y2 = mlp.predict(x2)

# %% [markdown]
# <h2>Real vs Predito</h2>

# %%
plt.clf()
plt.plot(x, y)
plt.scatter(x2, y2, marker='o', c='r')
plt.show()

# %% [markdown]
# <h2>Previsão para valores fora da faixa treinada</h2>

# %%
x = np.arange(0, 20, 1e-3)
x = x.reshape((len(x), 1))
y = np.sin(x)

# %%
trans_x = np.hstack([x, np.sin(x)])

# %%
mlp = MLPRegressor(hidden_layer_sizes=(100, 100, 100), solver='lbfgs')
mlp.fit(trans_x, y)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 100, 100), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='lbfgs', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
x2 = np.arange(11, 20, 1e-3)
x2 = x2.reshape((len(x2), 1))
trans_x2 = np.hstack([x2, np.sin(x2)])

# %%
y2 = mlp.predict(trans_x2)

# %%
# x2

# %%
x = np.arange(0, 20, 1e-3)
y = np.sin(x)

plt.plot(x, y)
plt.plot(x2, y2, c='r')
plt.show()
